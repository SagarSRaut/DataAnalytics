# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dm_office_sales.csv')
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
#Countplot: shows the total count of rows per category
# A histogram across a categorical, instead of quantitative 

plt.figure(figsize=(10,4),dpi=1000) #dpi = dots per inch
sns.countplot(x='level of education',data=df)
plt.show()

# %%
#with hue

plt.figure(figsize=(10,4),dpi=1000) #dpi = dots per inch
sns.countplot(x='level of education',data=df,hue='training level')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 #with hue
#       3 plt.figure(figsize=(10,4),dpi=1000) #dpi = dots per inch
# ----> 4 sns.countplot(x='level of education',data=df,hue='training level')
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
#Using palette

plt.figure(figsize=(10,4),dpi=1000) #dpi = dots per inch
sns.countplot(x='level of education',data=df,hue='training level',palette='Set1')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 4
#       1 #Using palette
#       3 plt.figure(figsize=(10,4),dpi=1000) #dpi = dots per inch
# ----> 4 sns.countplot(x='level of education',data=df,hue='training level',palette='Set1')
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
#Different palette

plt.figure(figsize=(10,4),dpi=1000) #dpi = dots per inch
sns.countplot(x='level of education',data=df,hue='training level',palette='Paired')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 #Different palette
#       3 plt.figure(figsize=(10,4),dpi=1000) #dpi = dots per inch
# ----> 4 sns.countplot(x='level of education',data=df,hue='training level',palette='Paired')
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# ...

# %%
#barplot
plt.figure(figsize=(10,6),dpi=200)
#by default barplot() will show mean
sns.barplot(x='level of education', y='salary',data=df,estimator=np.mean, errorbar='sd')
plt.show()

# %%
#

plt.figure(figsize=(10,6),dpi=200)
#by default barplot() will show mean
sns.barplot(x='level of education', y='salary',data=df,estimator=np.mean, errorbar='sd')
plt.show()
