# %%
import pandas as pd
dataset=pd.read_csv('salary.csv')
X=dataset.iloc[:,:-1].values  #take all the columns upto the salary column
y = dataset.iloc[:,1].values  #take the first column
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=1/3,random_state=0)

# %%
#Fit simple linear regression to the training data
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Make Prediction
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 40835.10590871, 123079.39940819,  65134.55626083,  63265.36777221,
#        115602.64545369, 108125.8914992 , 116537.23969801,  64199.96201652,
#         76349.68719258, 100649.1375447 ])

# %%
#Visualize training results
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train,color='r')
plt.plot(X_train, regressor.predict(X_train),color='b')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
print(regressor.predict(X_train))
# Out:
# Text(0, 0.5, 'Salary')

# %%
#visualize test results
#plot actual data points of test set
plt.scatter(X_test,y_test,color='r')
#plot the regression line(same as above)
plt.plot(X_train, regressor.predict(X_train),color='b')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
#Make new prediction
new_salary_pred = regressor.predict([[15]])
print('The preducted salary of a person of 15 years of experience is', new_salary_pred)
# Out:
# The preducted salary of a person of 15 years of experience is [167005.32889087]

# %%
# Intercept and coefficient
print('Intercept ... Fresher salary:', regressor.intercept_)
print("Coefficient ... Additional salary for each additional year's experience: ", regressor.coef_)
# Out:
# Intercept ... Fresher salary: 26816.19224403119
# Coefficient ... Additional salary for each additional year's experience:  [9345.94244312]

# %%
#evaluate results
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
MAE = mean_absolute_error(y_test,y_pred)
MSE = mean_squared_error(y_test,y_pred)
RMSE = np.sqrt(MSE)
print(f"MAE: {MAE}\nMSE: {MSE}\nRMSE: {RMSE}\n")
# Out:
# MAE: 3426.4269374307123
# MSE: 21026037.329511296
# RMSE: 4585.4157204675885
