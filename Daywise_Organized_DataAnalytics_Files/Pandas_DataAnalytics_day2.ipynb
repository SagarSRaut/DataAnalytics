# %% [markdown]
# #Creating a dataframe from csv
# #Exploratory data analysis

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name     CC Number Payment ID
# ...

# %%
print(df.columns) #column names
print(df.index) #index
print(df.head(5)) #first 5 rows
# Out:
# Index(['total_bill', 'tip', 'gender', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')
# RangeIndex(start=0, stop=244, step=1)
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1      Douglas Tucker  4.478070e+15    Sun4608
# 2      Travis Walters  6.011810e+15    Sun4458
# 3    Nathaniel Harris  4.676140e+15    Sun5260
# 4        Tonya Carter  4.832730e+15    Sun2251

# %%
print(df.tail(3)) #last 3 rows
print(df.info()) #information about the df including the data types and memory used
print(len(df)) #number of rows
# Out:
#      total_bill   tip  gender smoker   day    time  size  price_per_person  \
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name     CC Number Payment ID
# 241       Keith Wong  6.011890e+15    Sat3880
# 242     Dennis Dixon  4.375220e+12      Sat17
# 243  Michelle Hardin  3.511450e+15    Thur672
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   gender            244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
# ...

# %%
print(df.describe()) #statistical summary
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563495e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040732e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525320e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596450e+15

# %%
print(df.describe().transpose()) #statistical summary better organized
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563495e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040732e+13  3.525320e+15  4.553675e+15  6.596450e+15

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1      Douglas Tucker  4.478070e+15    Sun4608
# 2      Travis Walters  6.011810e+15    Sun4458
# 3    Nathaniel Harris  4.676140e+15    Sun5260
# 4        Tonya Carter  4.832730e+15    Sun2251

# %%
print(df['total_bill'])
print(type(df['total_bill']))
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
print(df[['total_bill','tip']]) #select multiple columns by providing a list of columns
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
#create new columns
df['tip_percentage'] = 100 * df['tip'] / df['total_bill']
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name     CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3.560330e+15    Sun2959        5.944673
# 1      Douglas Tucker  4.478070e+15    Sun4608       16.054159

# %%
#perform operations on existing columns / adjust existing columns
df['price_per_person'] = df['total_bill'] / df['size']
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2          8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3          3.446667
#
#            Payer Name     CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3.560330e+15    Sun2959        5.944673
# 1      Douglas Tucker  4.478070e+15    Sun4608       16.054159

# %%
df['price_per_person'] = np.round(df['price_per_person'],2) #roundoff to 2 places
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1      Douglas Tucker  4.478070e+15    Sun4608

# %%
#df = df.drop('tip_percentage',axis=1) ---> axis = 1 indicates column will be dropped
df.head(2)
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1      Douglas Tucker  4.478070e+15    Sun4608

# %%
#printing index
print(df.head(2))
df.index
# Out:
#    total_bill   tip  gender smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name     CC Number Payment ID
# 0  Christy Cunningham  3.560330e+15    Sun2959
# 1      Douglas Tucker  4.478070e+15    Sun4608
# RangeIndex(start=0, stop=244, step=1)

# %%
df = df.set_index('Payment ID') #sets index as per the given column name
df.head(2)
# Out:
#             total_bill   tip  gender smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name     CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3.560330e+15
# Sun4608                 3.45      Douglas Tucker  4.478070e+15

# %%
df = df.reset_index()
df.head(2)
# Out:
#   Payment ID  total_bill   tip  gender smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
#
#    price_per_person          Payer Name     CC Number
# 0              8.49  Christy Cunningham  3.560330e+15
# 1              3.45      Douglas Tucker  4.478070e+15

# %%
#Rows, get a single row, integer based
print(df.iloc[0])
# Out:
# total_bill                       16.99
# tip                               1.01
# gender                          Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number           3560330000000000.0
# Name: Sun2959, dtype: object

# %%
#df = df.set_index('Payment ID')
df.head(2)
# Out:
#             total_bill   tip  gender smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
#
#             price_per_person          Payer Name     CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3.560330e+15
# Sun4608                 3.45      Douglas Tucker  4.478070e+15

# %%
df.loc['Sun2959']
# Out:
# total_bill                       16.99
# tip                               1.01
# gender                          Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number           3560330000000000.0
# Name: Sun2959, dtype: object

# %%
#remove row
print(df.head(2))

# df = df.drop('Sun2959', axis=0)
print(df.head(2))
# Out:
#             total_bill   tip gender smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66   Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50   Male     No  Sun  Dinner     3
#
#             price_per_person      Payer Name     CC Number
# Payment ID
# Sun4608                 3.45  Douglas Tucker  4.478070e+15
# Sun4458                 7.00  Travis Walters  6.011810e+15
#             total_bill   tip gender smoker  day    time  size  \
# Payment ID
# Sun4608          10.34  1.66   Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50   Male     No  Sun  Dinner     3
#
#             price_per_person      Payer Name     CC Number
# Payment ID
# Sun4608                 3.45  Douglas Tucker  4.478070e+15
# Sun4458                 7.00  Travis Walters  6.011810e+15

# %%
#conditions
df = df.reset_index()
print(df['total_bill']>30) #returns boolean values
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# Name: total_bill, Length: 243, dtype: bool

# %%
bool_series = df['total_bill'] > 30
print(bool_series) #returns boolean
print(df[bool_series]) #returns the actual values  at all 'true' places
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# Name: total_bill, Length: 243, dtype: bool
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 10     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 22      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 38     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 43     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 46     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 51     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 55     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 58     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 82    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 84    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# ...

# %%
print(df[df['total_bill']>30]) #same output as above but this is a direct syntax
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 10     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 22      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 38     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 43     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 46     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 51     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 55     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 58     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 82    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 84    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 94     Fri9628       40.17   4.73    Male    Yes   Fri  Dinner     4
# 101    Sat6240       44.30   2.50  Female    Yes   Sat  Dinner     3
# 111     Sun591       38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
print(df.total_bill > 30) # same as df['total_bill']>30]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 238    False
# 239    False
# 240    False
# 241    False
# 242    False
# Name: total_bill, Length: 243, dtype: bool

# %%
print(df[df.total_bill > 30]) # same as df[df['total_bill']>30]
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 10     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 22      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 38     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 43     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 46     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 51     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 55     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 58     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 82    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 84    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 94     Fri9628       40.17   4.73    Male    Yes   Fri  Dinner     4
# 101    Sat6240       44.30   2.50  Female    Yes   Sat  Dinner     3
# 111     Sun591       38.07   4.00    Male     No   Sun  Dinner     3
# ...

# %%
df[df['gender'] == 'Female']
# Out:
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 3      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# 10     Sun6686       35.26  5.00  Female     No   Sun  Dinner     4
# 13     Sun3848       14.83  3.02  Female     No   Sun  Dinner     2
# 15     Sun9715       10.33  1.67  Female     No   Sun  Dinner     3
# 17     Sun2789       16.97  3.50  Female     No   Sun  Dinner     3
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 225    Fri6359       10.09  2.00  Female    Yes   Fri   Lunch     2
# 228    Sat3943       22.12  2.88  Female    Yes   Sat  Dinner     2
# 237    Sat9777       35.83  4.67  Female     No   Sat  Dinner     3
# 239    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 242    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person        Payer Name     CC Number
# 3                6.15      Tonya Carter  4.832730e+15
# ...

# %%
#Multiple conditions
df_new = df[(df['total_bill'] > 30) & (df['gender'] == 'Male')]
df_new
# Out:
#     Payment ID  total_bill    tip gender smoker   day    time  size  \
# 22      Sat239       39.42   7.58   Male     No   Sat  Dinner     4
# 38     Sat6373       31.27   5.00   Male     No   Sat  Dinner     3
# 43     Sun2274       30.40   5.60   Male     No   Sun  Dinner     4
# 46     Sun9677       32.40   6.00   Male     No   Sun  Dinner     4
# 55     Sat8903       38.01   3.00   Male    Yes   Sat  Dinner     4
# 58     Sat8139       48.27   6.73   Male     No   Sat  Dinner     4
# 82    Thur8801       32.68   5.00   Male    Yes  Thur   Lunch     2
# 94     Fri9628       40.17   4.73   Male    Yes   Fri  Dinner     4
# 111     Sun591       38.07   4.00   Male     No   Sun  Dinner     3
# 140   Thur1025       34.30   6.70   Male     No  Thur   Lunch     6
# 141   Thur3621       41.19   5.00   Male     No  Thur   Lunch     5
# 155    Sun7518       48.17   5.00   Male     No   Sun  Dinner     6
# 166    Sun3719       31.71   4.50   Male     No   Sun  Dinner     4
# ...

# %%
df_new = df[(df['total_bill'] > 30) & ~(df['gender'] == 'Female')]
df_new
# Out:
#     Payment ID  total_bill    tip gender smoker   day    time  size  \
# 22      Sat239       39.42   7.58   Male     No   Sat  Dinner     4
# 38     Sat6373       31.27   5.00   Male     No   Sat  Dinner     3
# 43     Sun2274       30.40   5.60   Male     No   Sun  Dinner     4
# 46     Sun9677       32.40   6.00   Male     No   Sun  Dinner     4
# 55     Sat8903       38.01   3.00   Male    Yes   Sat  Dinner     4
# 58     Sat8139       48.27   6.73   Male     No   Sat  Dinner     4
# 82    Thur8801       32.68   5.00   Male    Yes  Thur   Lunch     2
# 94     Fri9628       40.17   4.73   Male    Yes   Fri  Dinner     4
# 111     Sun591       38.07   4.00   Male     No   Sun  Dinner     3
# 140   Thur1025       34.30   6.70   Male     No  Thur   Lunch     6
# 141   Thur3621       41.19   5.00   Male     No  Thur   Lunch     5
# 155    Sun7518       48.17   5.00   Male     No   Sun  Dinner     6
# 166    Sun3719       31.71   4.50   Male     No   Sun  Dinner     4
# ...

# %%
df_new = df[(df['total_bill'] > 30) & (df['gender'] != 'Female')]
df_new
# Out:
#     Payment ID  total_bill    tip gender smoker   day    time  size  \
# 22      Sat239       39.42   7.58   Male     No   Sat  Dinner     4
# 38     Sat6373       31.27   5.00   Male     No   Sat  Dinner     3
# 43     Sun2274       30.40   5.60   Male     No   Sun  Dinner     4
# 46     Sun9677       32.40   6.00   Male     No   Sun  Dinner     4
# 55     Sat8903       38.01   3.00   Male    Yes   Sat  Dinner     4
# 58     Sat8139       48.27   6.73   Male     No   Sat  Dinner     4
# 82    Thur8801       32.68   5.00   Male    Yes  Thur   Lunch     2
# 94     Fri9628       40.17   4.73   Male    Yes   Fri  Dinner     4
# 111     Sun591       38.07   4.00   Male     No   Sun  Dinner     3
# 140   Thur1025       34.30   6.70   Male     No  Thur   Lunch     6
# 141   Thur3621       41.19   5.00   Male     No  Thur   Lunch     5
# 155    Sun7518       48.17   5.00   Male     No   Sun  Dinner     6
# 166    Sun3719       31.71   4.50   Male     No   Sun  Dinner     4
# ...

# %%
df_new = df[(df['total_bill'] > 30) | (df['tip'] > 5)]
df_new
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 10     Sun6686       35.26   5.00  Female     No   Sun  Dinner     4
# 22      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 38     Sat6373       31.27   5.00    Male     No   Sat  Dinner     3
# 43     Sun2274       30.40   5.60    Male     No   Sun  Dinner     4
# 46     Sun9677       32.40   6.00    Male     No   Sun  Dinner     4
# 51     Sun6165       34.81   5.20  Female     No   Sun  Dinner     4
# 55     Sat8903       38.01   3.00    Male    Yes   Sat  Dinner     4
# 58     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 82    Thur8801       32.68   5.00    Male    Yes  Thur   Lunch     2
# 84    Thur7972       34.83   5.17  Female     No  Thur   Lunch     4
# 87    Thur9003       24.71   5.85    Male     No  Thur   Lunch     2
# 94     Fri9628       40.17   4.73    Male    Yes   Fri  Dinner     4
# 101    Sat6240       44.30   2.50  Female    Yes   Sat  Dinner     3
# ...

# %%
# conditinal is in operator
options = ['Sat','Sun']
df['day'].isin(options) # this is same as df[df['day'].isin(['Sat','Sun'])])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 238     True
# 239     True
# 240     True
# 241     True
# 242    False
# Name: day, Length: 243, dtype: bool

# %%
#sorting
df.sort_values('tip')
# Out:
#     Payment ID  total_bill    tip  gender smoker   day    time  size  \
# 235    Sat5032       12.60   1.00    Male    Yes   Sat  Dinner     2
# 110    Sat4801        7.25   1.00  Female     No   Sat  Dinner     1
# 91     Fri3780        5.75   1.00  Female    Yes   Fri  Dinner     2
# 66     Sat3455        3.07   1.00  Female    Yes   Sat  Dinner     1
# 214    Sat6983       12.90   1.10  Female    Yes   Sat  Dinner     2
# ..         ...         ...    ...     ...    ...   ...     ...   ...
# 140   Thur1025       34.30   6.70    Male     No  Thur   Lunch     6
# 58     Sat8139       48.27   6.73    Male     No   Sat  Dinner     4
# 22      Sat239       39.42   7.58    Male     No   Sat  Dinner     4
# 211    Sat4590       48.33   9.00    Male     No   Sat  Dinner     4
# 169    Sat1954       50.81  10.00    Male    Yes   Sat  Dinner     3
#
#      price_per_person       Payer Name     CC Number
# 235              6.30    Matthew Myers  3.543680e+15
# ...

# %%
#correlation
print(df[['total_bill','tip']].corr())
# Out:
#             total_bill       tip
# total_bill    1.000000  0.676901
# tip           0.676901  1.000000

# %%
#value_counts
print(df['smoker'].value_counts())
df['gender'].value_counts()
# Out:
# smoker
# No     150
# Yes     93
# Name: count, dtype: int64
# gender
# Male      157
# Female     86
# Name: count, dtype: int64

# %%
#unique 
print(df['size'].unique) #unique values as an array
print(df['size'].nunique) #number of unique values
print(df['time'].unique) #for a character column
# Out:
# <bound method Series.unique of 0      3
# 1      3
# 2      2
# 3      4
# 4      4
#       ..
# 238    3
# 239    2
# 240    2
# 241    2
# 242    2
# Name: size, Length: 243, dtype: int64>
# <bound method IndexOpsMixin.nunique of 0      3
# 1      3
# 2      2
# 3      4
# 4      4
#       ..
# 238    3
# 239    2
# 240    2
# 241    2
# 242    2
# Name: size, Length: 243, dtype: int64>
# <bound method Series.unique of 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 238    Dinner
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# Name: time, Length: 243, dtype: object>

# %%
#between: options for inclusive are both left, right, neither

print(df['total_bill'].between(10,20,inclusive='both')) #True False
print(df[df['total_bill'].between(10,20,inclusive='both')]) #actual values
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 238    False
# 239    False
# 240    False
# 241     True
# 242     True
# Name: total_bill, Length: 243, dtype: bool
#     Payment ID  total_bill   tip  gender smoker   day    time  size  \
# 0      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 7      Sun6820       15.04  1.96    Male     No   Sun  Dinner     2
# 8      Sun3775       14.78  3.23    Male     No   Sun  Dinner     2
# 9      Sun2546       10.27  1.71    Male     No   Sun  Dinner     2
# 11     Sun1300       15.42  1.57    Male     No   Sun  Dinner     2
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 233    Sat7220       15.53  3.00    Male    Yes   Sat  Dinner     2
# 234    Sat4615       10.07  1.25    Male     No   Sat  Dinner     2
# 235    Sat5032       12.60  1.00    Male    Yes   Sat  Dinner     2
# 241      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# ...
